# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/trends-in-consumer/trend_consumer new.csv

# %%
df=pd.read_csv('/kaggle/input/trends-in-consumer/trend_consumer new.csv')
df.sample(10)
# Out:
#     Date received                                            Product  \
# 247    2024-06-26  Credit reporting or other personal consumer re...
# 9      2024-05-24                                    Debt collection
# 395    2024-06-28  Credit reporting or other personal consumer re...
# 191    2024-06-24  Credit reporting or other personal consumer re...
# 339    2024-06-27  Credit reporting or other personal consumer re...
# 219    2024-06-25  Credit reporting or other personal consumer re...
# 549    2024-06-28  Credit reporting or other personal consumer re...
# 86     2024-06-13  Credit reporting or other personal consumer re...
# 455    2024-06-28  Credit reporting or other personal consumer re...
# 565    2024-06-29  Credit reporting or other personal consumer re...
#
#           Sub-product                                              Issue  \
# 247  Credit reporting               Incorrect information on your report
# 9    Credit card debt                  Attempts to collect debt not owed
# 395  Credit reporting               Incorrect information on your report
# 191  Credit reporting                        Improper use of your report
# 339  Credit reporting               Incorrect information on your report
# 219  Credit reporting                        Improper use of your report
# 549  Credit reporting               Incorrect information on your report
# 86   Credit reporting                        Improper use of your report
# 455  Credit reporting  Problem with a company's investigation into an...
# 565  Credit reporting                        Improper use of your report
#
#                                              Sub-issue  \
# 247                           Account status incorrect
# 9                    Debt was result of identity theft
# 395                           Account status incorrect
# 191      Reporting company used your report improperly
# 339                      Account information incorrect
# 219      Reporting company used your report improperly
# 549                           Account status incorrect
# 86       Reporting company used your report improperly
# 455  Their investigation did not fix an error on yo...
# 565  Credit inquiries on your report that you don't...
#
#                                  Company State ZIP code Submitted via  \
# 247  Experian Information Solutions Inc.    NY    11411           Web
# 9         Bread Financial Holdings, Inc.    CA    95818           Web
# 395  Experian Information Solutions Inc.    MD    20853           Web
# 191  Experian Information Solutions Inc.    NJ     7024           Web
# 339                        EQUIFAX, INC.    GA    30046           Web
# 219                        EQUIFAX, INC.    FL    33025           Web
# 549                        EQUIFAX, INC.    PA    19606           Web
# 86   Experian Information Solutions Inc.    WA    98444           Web
# 455  Experian Information Solutions Inc.    MI    48183           Web
# 565            Open Dealer Exchange, LLC    AZ    85210           Web
#
#     Date sent to company Company response to consumer Timely response?  \
# 247           2024-06-26                  In progress              Yes
# 9             2024-05-24      Closed with explanation              Yes
# 395           2024-06-28                  In progress              Yes
# 191           2024-06-24                  In progress              Yes
# 339           2024-06-27                  In progress              Yes
# 219           2024-06-25                  In progress              Yes
# 549           2024-06-28                  In progress              Yes
# 86            2024-06-13                  In progress              Yes
# 455           2024-06-28                  In progress              Yes
# 565           2024-06-29                  In progress              Yes
#
#      Consumer disputed?  Complaint ID
# 247                 NaN       9349952
# 9                   NaN       9089032
# 395                 NaN       9376104
# 191                 NaN       9341291
# 339                 NaN       9362348
# 219                 NaN       9336492
# 549                 NaN       9378949
# 86                  NaN       9239977
# 455                 NaN       9378562
# 565                 NaN       9382421

# %%
df.isna().sum()
# Out:
# Date received                     0
# Product                           0
# Sub-product                       0
# Issue                             0
# Sub-issue                         0
# Company                           0
# State                             0
# ZIP code                          0
# Submitted via                     0
# Date sent to company              0
# Company response to consumer      0
# Timely response?                  0
# Consumer disputed?              590
# Complaint ID                      0
# dtype: int64

# %%
df.drop('Consumer disputed?',axis=1, inplace=True)

# %%
df.sample(5)
# Out:
#     Date received                                            Product  \
# 411    2024-06-28  Credit reporting or other personal consumer re...
# 463    2024-06-28  Credit reporting or other personal consumer re...
# 376    2024-06-28  Credit reporting or other personal consumer re...
# 202    2024-06-25                                    Debt collection
# 175    2024-06-24  Credit reporting or other personal consumer re...
#
#           Sub-product                                 Issue  \
# 411  Credit reporting           Improper use of your report
# 463  Credit reporting           Improper use of your report
# 376  Credit reporting  Incorrect information on your report
# 202     I do not know    False statements or representation
# 175  Credit reporting           Improper use of your report
#
#                                              Sub-issue  \
# 411      Reporting company used your report improperly
# 463  Credit inquiries on your report that you don't...
# 376                Information belongs to someone else
# 202                  Attempted to collect wrong amount
# 175  Credit inquiries on your report that you don't...
#
#                                              Company State ZIP code  \
# 411              Experian Information Solutions Inc.    FL    33033
# 463                                    EQUIFAX, INC.    NC    27801
# 376           TRANSUNION INTERMEDIATE HOLDINGS, INC.    IL    60639
# 202  Continental Services Group, Inc. d/b/a ConServe    PA    152XX
# 175                                    EQUIFAX, INC.    CA    95838
#
#     Submitted via Date sent to company Company response to consumer  \
# 411           Web           2024-06-28                  In progress
# 463           Web           2024-06-28                  In progress
# 376           Web           2024-06-28                  In progress
# 202           Web           2024-06-25      Closed with explanation
# 175           Web           2024-06-24                  In progress
#
#     Timely response?  Complaint ID
# 411              Yes       9373839
# 463              Yes       9379263
# 376              Yes       9373334
# 202              Yes       9335052
# 175              Yes       9357009

# %%
file_name = 'consumer_trends.xlsx'
 
df.to_excel(file_name)
